# %%
import tensorflow as tf
import numpy as np
import os
from sklearn.preprocessing import LabelEncoder
import re
import collections
import random
import time

class Model_vec:
    
    def __init__(self, batch_size, dimension_size, learning_rate, vocabulary_size):
        self.train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
        self.train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
        embeddings = tf.Variable(tf.random_uniform([vocabulary_size, dimension_size], -1.0, 1.0))
        embed = tf.nn.embedding_lookup(embeddings, self.train_inputs)
        self.nce_weights = tf.Variable(tf.truncated_normal([vocabulary_size, dimension_size], stddev = 1.0 / np.sqrt(dimension_size)))
        self.nce_biases = tf.Variable(tf.zeros([vocabulary_size]))
        self.loss = tf.reduce_mean(tf.nn.nce_loss(weights = self.nce_weights, biases = self.nce_biases, labels = self.train_labels,
                                                  inputs=embed, num_sampled = batch_size / 2, num_classes = vocabulary_size))
        self.optimizer = tf.train.AdamOptimizer(learning_rate).minimize(self.loss)
        self.norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
        self.normalized_embeddings = embeddings / self.norm
        
class Model:
    def __init__(self, sequence_length, dimension_input, dimension_output, 
                 learning_rate, filter_sizes, out_dimension):
        self.X = tf.placeholder(tf.float32, shape=[None, sequence_length, dimension_input, 1])
        self.Y = tf.placeholder(tf.float32, shape=[None, dimension_output])
        pooled_outputs = []
        for i in filter_sizes:
            w = tf.Variable(tf.truncated_normal([i, dimension_input, 1, out_dimension], stddev=0.1))
            b = tf.Variable(tf.truncated_normal([out_dimension], stddev = 0.01))
            conv = tf.nn.relu(tf.nn.conv2d(self.X, w, strides=[1, 1, 1, 1],padding="VALID") + b)
            pooled = tf.nn.max_pool(conv,ksize=[1, sequence_length - i + 1, 1, 1],strides=[1, 1, 1, 1],padding='VALID')
            pooled_outputs.append(pooled)
        h_pool = tf.concat(pooled_outputs, 3)
        h_pool_flat = tf.nn.dropout(tf.reshape(h_pool, [-1, out_dimension * len(filter_sizes)]), 0.1)
        w = tf.Variable(tf.truncated_normal([out_dimension * len(filter_sizes), dimension_output], stddev=0.1))
        b = tf.Variable(tf.truncated_normal([dimension_output], stddev = 0.01))
        self.logits = tf.matmul(h_pool_flat, w) + b
        self.cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits = self.logits, labels = self.Y))
        l2 = sum(0.0005 * tf.nn.l2_loss(tf_var) for tf_var in tf.trainable_variables())
        self.cost += l2
        self.optimizer = tf.train.AdamOptimizer(learning_rate = learning_rate).minimize(self.cost)
        self.correct_pred = tf.equal(tf.argmax(self.logits, 1), tf.argmax(self.Y, 1))
        self.accuracy = tf.reduce_mean(tf.cast(self.correct_pred, tf.float32))

# %%
def clearstring(string):
    string = re.sub('[^\'\"A-Za-z0-9 ]+', '', string)
    string = string.split(' ')
    string = filter(None, string)
    string = [y.strip() for y in string]
    return ' '.join(string)

def read_data():
    list_folder = os.listdir('data/')
    label = list_folder
    label.sort()
    outer_string, outer_label = [], []
    for i in range(len(list_folder)):
        list_file = os.listdir('data/' + list_folder[i])
        strings = []
        for x in range(len(list_file)):
            with open('data/' + list_folder[i] + '/' + list_file[x], 'r') as fopen:
                strings += fopen.read().split('\n')
        strings = list(filter(None, strings))
        for k in range(len(strings)):
            strings[k] = clearstring(strings[k])
        labels = [i] * len(strings)
        outer_string += strings
        outer_label += labels
    
    dataset = np.array([outer_string, outer_label])
    dataset = dataset.T
    np.random.shuffle(dataset)
    
    string = []
    for i in range(dataset.shape[0]):
        string += dataset[i][0].split()
    
    return string, dataset, label

# %%
def build_dataset(words, vocabulary_size):
    count = []
    count.extend(collections.Counter(words).most_common(vocabulary_size))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary) + 1
    data = []
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        data.append(index)
    dictionary['PAD'] = 0
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, dictionary, reverse_dictionary

def generate_batch_skipgram(words, batch_size, num_skips, skip_window):
    data_index = 0
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1
    buffer = collections.deque(maxlen=span)
    for i in range(span):
        buffer.append(words[data_index])
        data_index = (data_index + 1) % len(words)
    for i in range(batch_size // num_skips):
        target = skip_window
        targets_to_avoid = [skip_window]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(words[data_index])
        data_index = (data_index + 1) % len(words)
    data_index = (data_index + len(words) - span) % len(words)
    return batch, labels

def generatevector(dimension, batch_size, skip_size, skip_window, num_skips, iteration, words_real):
    
    print ("Data size:", len(words_real))
    data, dictionary, reverse_dictionary = build_dataset(words_real, len(words_real))
    sess = tf.InteractiveSession()
    print ("Creating Word2Vec model..")
    model = Model_vec(batch_size, dimension, 0.1, len(dictionary))
    sess.run(tf.global_variables_initializer())
    last_time = time.time()
    for step in range(iteration):
        new_time = time.time()
        batch_inputs, batch_labels = generate_batch_skipgram(data, batch_size, num_skips, skip_window)
        feed_dict = {model.train_inputs: batch_inputs, model.train_labels: batch_labels}
        _, loss = sess.run([model.optimizer, model.loss], feed_dict=feed_dict)
        if ((step + 1) % 1000) == 0:
            print ("epoch:", step + 1, ", loss:", loss, ", speed:", (time.time() - new_time) * 1000, "s / 1000 epoch")
    tf.reset_default_graph()       
    return dictionary, reverse_dictionary, model.normalized_embeddings.eval()

# %%
string, data, label = read_data()
maxlen = 50
location = os.getcwd()
dimension = 512
skip_size = 8
skip_window = 1
num_skips = 2
iteration_train_vectors = 20000
size_layer = 128
learning_rate = 0.0001
epoch = 100
filter_sizes = [2,3,4,5]
batch = 100

# %%
dictionary, reverse_dictionary, vectors = generatevector(dimension, 32, skip_size, skip_window, num_skips, iteration_train_vectors, string)
# Out:
# Data size: 72822
# Creating Word2Vec model..
# epoch: 1000 , loss: 26.4191 , speed: 10.108232498168945 s / 1000 epoch
# epoch: 2000 , loss: 9.94636 , speed: 10.172843933105469 s / 1000 epoch
# epoch: 3000 , loss: 21.9353 , speed: 10.111331939697266 s / 1000 epoch
# epoch: 4000 , loss: 0.229738 , speed: 10.18381118774414 s / 1000 epoch
# epoch: 5000 , loss: 2.6353 , speed: 10.280370712280273 s / 1000 epoch
# epoch: 6000 , loss: 0.594088 , speed: 10.149240493774414 s / 1000 epoch
# epoch: 7000 , loss: 1.70112 , speed: 10.061502456665039 s / 1000 epoch
# epoch: 8000 , loss: 10.6174 , speed: 10.412931442260742 s / 1000 epoch
# epoch: 9000 , loss: 0.461871 , speed: 10.251045227050781 s / 1000 epoch
# epoch: 10000 , loss: 0.0962568 , speed: 10.248184204101562 s / 1000 epoch
# epoch: 11000 , loss: 1.08778 , speed: 10.14256477355957 s / 1000 epoch
# epoch: 12000 , loss: 0.103811 , speed: 10.224103927612305 s / 1000 epoch
# epoch: 13000 , loss: 0.171167 , speed: 9.927749633789062 s / 1000 epoch
# epoch: 14000 , loss: 1.09419 , speed: 10.217428207397461 s / 1000 epoch
# epoch: 15000 , loss: 8.17198 , speed: 10.253190994262695 s / 1000 epoch
# epoch: 16000 , loss: 1.70933 , speed: 10.183334350585938 s / 1000 epoch
# epoch: 17000 , loss: 4.34536 , speed: 10.096073150634766 s / 1000 epoch
# epoch: 18000 , loss: 0.610711 , speed: 10.050535202026367 s / 1000 epoch
# epoch: 19000 , loss: 0.517664 , speed: 10.176658630371094 s / 1000 epoch
# epoch: 20000 , loss: 9.51103 , speed: 10.19287109375 s / 1000 epoch

# %%
from sklearn.cross_validation import train_test_split
train_X, test_X, train_Y, test_Y = train_test_split(data[:, 0], data[:, 1], test_size = 0.2)
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
tf.reset_default_graph()
sess = tf.InteractiveSession()
model = Model(maxlen, dimension, len(label), learning_rate, [2,3,4], size_layer)
sess.run(tf.global_variables_initializer())
saver = tf.train.Saver(tf.global_variables())
EARLY_STOPPING, CURRENT_CHECKPOINT, CURRENT_ACC, EPOCH = 100, 0, 0, 0
while True:
    if CURRENT_CHECKPOINT == EARLY_STOPPING:
        print('break epoch:', EPOCH)
        break
    train_acc, train_loss, test_acc, test_loss = 0, 0, 0, 0
    for i in range(0, (train_X.shape[0] // batch) * batch, batch):
        batch_x = np.zeros((batch, maxlen, dimension))
        batch_y = np.zeros((batch, len(label)))
        for k in range(batch):
            tokens = train_X[i + k].split()[:maxlen]
            for no, text in enumerate(tokens[::-1]):
                try:
                    batch_x[k, -1 - no, :] += vectors[dictionary[text], :]
                except:
                    continue
            batch_y[k, int(train_Y[i + k])] = 1.0
        batch_x = np.expand_dims(batch_x, axis=-1)
        loss, _ = sess.run([model.cost, model.optimizer], feed_dict = {model.X : batch_x, model.Y : batch_y})
        train_loss += loss
        train_acc += sess.run(model.accuracy, feed_dict = {model.X : batch_x, model.Y : batch_y})
    
    for i in range(0, (test_X.shape[0] // batch) * batch, batch):
        batch_x = np.zeros((batch, maxlen, dimension))
        batch_y = np.zeros((batch, len(label)))
        for k in range(batch):
            tokens = test_X[i + k].split()[:maxlen]
            for no, text in enumerate(tokens[::-1]):
                try:
                    batch_x[k, -1 - no, :] += vectors[dictionary[text], :]
                except:
                    continue
            batch_y[k, int(test_Y[i + k])] = 1.0
        batch_x = np.expand_dims(batch_x, axis=-1)
        loss, acc = sess.run([model.cost, model.accuracy], feed_dict = {model.X : batch_x, model.Y : batch_y})
        test_loss += loss
        test_acc += acc
        
    train_loss /= (train_X.shape[0] // batch)
    train_acc /= (train_X.shape[0] // batch)
    test_loss /= (test_X.shape[0] // batch)
    test_acc /= (test_X.shape[0] // batch)
    if test_acc > CURRENT_ACC:
        print('epoch:', EPOCH, ', pass acc:', CURRENT_ACC, ', current acc:', test_acc)
        CURRENT_ACC = test_acc
        CURRENT_CHECKPOINT = 0
        saver.save(sess, os.getcwd() + "/model-cnn-vector.ckpt")
    else:
        CURRENT_CHECKPOINT += 1
    EPOCH += 1
    print('epoch:', EPOCH, ', training loss:', train_loss, ', training acc:', train_acc, ', valid loss:', test_loss, ', valid acc:', test_acc)
# Out:
# epoch: 0 , pass acc: 0 , current acc: 0.569999953111
# epoch: 1 , training loss: 2.1690743821 , training acc: 0.534285690103 , valid loss: 2.09954635302 , valid acc: 0.569999953111
# epoch: 2 , training loss: 2.1325142639 , training acc: 0.555714270898 , valid loss: 2.14290912946 , valid acc: 0.543333311876
# epoch: 3 , training loss: 2.09860954114 , training acc: 0.570714273623 , valid loss: 2.1156903108 , valid acc: 0.513333340486
# epoch: 4 , training loss: 2.06246621268 , training acc: 0.600714262043 , valid loss: 2.20896625519 , valid acc: 0.523333321015
# epoch: 4 , pass acc: 0.569999953111 , current acc: 0.599999964237
# epoch: 5 , training loss: 2.0325673478 , training acc: 0.612142833216 , valid loss: 2.13578724861 , valid acc: 0.599999964237
# epoch: 5 , pass acc: 0.599999964237 , current acc: 0.619999965032
# epoch: 6 , training loss: 2.0317456552 , training acc: 0.612857120378 , valid loss: 2.01069108645 , valid acc: 0.619999965032
# epoch: 7 , training loss: 2.01486952816 , training acc: 0.59428568823 , valid loss: 2.07608016332 , valid acc: 0.596666653951
# epoch: 7 , pass acc: 0.619999965032 , current acc: 0.620000004768
# epoch: 8 , training loss: 2.02039587498 , training acc: 0.60928569947 , valid loss: 2.02282834053 , valid acc: 0.620000004768
# epoch: 9 , training loss: 2.0516422987 , training acc: 0.592142828873 , valid loss: 2.1519668897 , valid acc: 0.573333303134
# epoch: 10 , training loss: 1.9865090847 , training acc: 0.597142836877 , valid loss: 2.0203974247 , valid acc: 0.586666623751
# epoch: 10 , pass acc: 0.620000004768 , current acc: 0.629999995232
# epoch: 11 , training loss: 1.99190739223 , training acc: 0.627857135875 , valid loss: 1.97177620729 , valid acc: 0.629999995232
# epoch: 12 , training loss: 1.98150954076 , training acc: 0.619285685675 , valid loss: 2.03733650843 , valid acc: 0.576666633288
# epoch: 13 , training loss: 1.97421237401 , training acc: 0.630714258977 , valid loss: 1.98372244835 , valid acc: 0.613333304723
# epoch: 14 , training loss: 1.94085575002 , training acc: 0.602142853396 , valid loss: 2.04735676448 , valid acc: 0.579999983311
# epoch: 15 , training loss: 1.96664679902 , training acc: 0.641428555761 , valid loss: 2.01619823774 , valid acc: 0.593333323797
# epoch: 16 , training loss: 1.8904363513 , training acc: 0.617142830576 , valid loss: 1.98257637024 , valid acc: 0.596666634083
# epoch: 17 , training loss: 1.88767501286 , training acc: 0.620714251484 , valid loss: 1.96244736513 , valid acc: 0.586666663488
# epoch: 18 , training loss: 1.89068206719 , training acc: 0.619285689933 , valid loss: 1.87416048845 , valid acc: 0.603333334128
# epoch: 19 , training loss: 1.91700860432 , training acc: 0.634999986206 , valid loss: 1.90875061353 , valid acc: 0.576666653156
# epoch: 20 , training loss: 1.83219099896 , training acc: 0.628571403878 , valid loss: 1.87877523899 , valid acc: 0.629999995232
# epoch: 21 , training loss: 1.87834803547 , training acc: 0.644999980927 , valid loss: 2.00534745057 , valid acc: 0.593333303928
# epoch: 22 , training loss: 1.87137508392 , training acc: 0.623571412904 , valid loss: 1.9965509971 , valid acc: 0.59000001351
# epoch: 23 , training loss: 1.84573789154 , training acc: 0.612857128893 , valid loss: 2.02530654271 , valid acc: 0.559999982516
# epoch: 24 , training loss: 1.87557589156 , training acc: 0.63071427175 , valid loss: 1.95343534152 , valid acc: 0.623333315055
# epoch: 24 , pass acc: 0.629999995232 , current acc: 0.636666675409
# epoch: 25 , training loss: 1.8493433765 , training acc: 0.629285693169 , valid loss: 1.7747768561 , valid acc: 0.636666675409
# epoch: 25 , pass acc: 0.636666675409 , current acc: 0.639999965827
# epoch: 26 , training loss: 1.80820089579 , training acc: 0.638571398599 , valid loss: 1.83090257645 , valid acc: 0.639999965827
# epoch: 27 , training loss: 1.79527048554 , training acc: 0.637857124209 , valid loss: 1.9399433136 , valid acc: 0.606666644414
# epoch: 28 , training loss: 1.80390152761 , training acc: 0.628571412393 , valid loss: 1.91603338718 , valid acc: 0.58666664362
# epoch: 29 , training loss: 1.78198550429 , training acc: 0.652142835515 , valid loss: 1.85130167007 , valid acc: 0.616666634878
# epoch: 30 , training loss: 1.80247183357 , training acc: 0.644285695893 , valid loss: 1.91695110003 , valid acc: 0.599999984105
# epoch: 31 , training loss: 1.77808686665 , training acc: 0.657142839261 , valid loss: 1.87011190255 , valid acc: 0.616666654746
# epoch: 32 , training loss: 1.79873134409 , training acc: 0.654999979905 , valid loss: 1.9894610246 , valid acc: 0.593333303928
# epoch: 33 , training loss: 1.74420399325 , training acc: 0.641428547246 , valid loss: 1.83563705285 , valid acc: 0.619999965032
# epoch: 34 , training loss: 1.76996166365 , training acc: 0.647142836026 , valid loss: 1.86965223153 , valid acc: 0.626666665077
# epoch: 35 , training loss: 1.74109644549 , training acc: 0.647857142346 , valid loss: 1.82455086708 , valid acc: 0.599999984105
# epoch: 36 , training loss: 1.77251940114 , training acc: 0.65285713332 , valid loss: 1.83906129996 , valid acc: 0.599999964237
# epoch: 37 , training loss: 1.73713595527 , training acc: 0.628571412393 , valid loss: 1.93447025617 , valid acc: 0.576666633288
# epoch: 38 , training loss: 1.70015076229 , training acc: 0.637857130596 , valid loss: 1.81454714139 , valid acc: 0.609999974569
# epoch: 39 , training loss: 1.72448865856 , training acc: 0.657857111522 , valid loss: 1.88437485695 , valid acc: 0.609999974569
# epoch: 40 , training loss: 1.72753846645 , training acc: 0.645714257445 , valid loss: 1.75439771016 , valid acc: 0.63666665554
# epoch: 41 , training loss: 1.71148304428 , training acc: 0.664999974625 , valid loss: 1.8261526823 , valid acc: 0.613333304723
# epoch: 42 , training loss: 1.73530711446 , training acc: 0.665714272431 , valid loss: 1.76018679142 , valid acc: 0.636666635672
# epoch: 43 , training loss: 1.67713110788 , training acc: 0.657142830747 , valid loss: 1.8542517821 , valid acc: 0.589999973774
# epoch: 43 , pass acc: 0.639999965827 , current acc: 0.666666646798
# epoch: 44 , training loss: 1.67744264432 , training acc: 0.637857117823 , valid loss: 1.7126651605 , valid acc: 0.666666646798
# epoch: 45 , training loss: 1.67596256733 , training acc: 0.672142846244 , valid loss: 1.75476813316 , valid acc: 0.626666645209
# epoch: 46 , training loss: 1.67876948629 , training acc: 0.630714258977 , valid loss: 1.79901659489 , valid acc: 0.633333325386
# epoch: 47 , training loss: 1.66642464059 , training acc: 0.644285704408 , valid loss: 1.70424795151 , valid acc: 0.659999966621
# epoch: 48 , training loss: 1.65816508021 , training acc: 0.647142848798 , valid loss: 1.76129754384 , valid acc: 0.576666633288
# epoch: 49 , training loss: 1.6216223325 , training acc: 0.672857118504 , valid loss: 1.7747909228 , valid acc: 0.569999972979
# epoch: 50 , training loss: 1.65642027344 , training acc: 0.657142830747 , valid loss: 1.80209537347 , valid acc: 0.616666634878
# epoch: 51 , training loss: 1.63969218731 , training acc: 0.672142841986 , valid loss: 1.73377569516 , valid acc: 0.596666653951
# epoch: 52 , training loss: 1.61965979849 , training acc: 0.662857128041 , valid loss: 1.75036716461 , valid acc: 0.586666623751
# epoch: 53 , training loss: 1.62056885447 , training acc: 0.672142841986 , valid loss: 1.81534341971 , valid acc: 0.573333303134
# epoch: 54 , training loss: 1.61434389012 , training acc: 0.669999969857 , valid loss: 1.77265834808 , valid acc: 0.616666674614
# epoch: 55 , training loss: 1.59360596963 , training acc: 0.662142834493 , valid loss: 1.7471057574 , valid acc: 0.606666644414
# epoch: 56 , training loss: 1.62176640545 , training acc: 0.672857118504 , valid loss: 1.76114726067 , valid acc: 0.643333295981
# epoch: 57 , training loss: 1.61129684108 , training acc: 0.68285712174 , valid loss: 1.6897444725 , valid acc: 0.623333315055
# epoch: 58 , training loss: 1.56226963656 , training acc: 0.659999975136 , valid loss: 1.65738566717 , valid acc: 0.649999996026
# epoch: 59 , training loss: 1.59609056371 , training acc: 0.68857141052 , valid loss: 1.6984282732 , valid acc: 0.609999994437
# epoch: 60 , training loss: 1.557739079 , training acc: 0.683571406773 , valid loss: 1.72628641129 , valid acc: 0.60333331426
# epoch: 61 , training loss: 1.56217100791 , training acc: 0.685714270387 , valid loss: 1.62810826302 , valid acc: 0.666666646798
# epoch: 62 , training loss: 1.5464478646 , training acc: 0.682857117483 , valid loss: 1.74197351933 , valid acc: 0.623333315055
# epoch: 63 , training loss: 1.54342799527 , training acc: 0.681428534644 , valid loss: 1.73484798272 , valid acc: 0.59333328406
# epoch: 64 , training loss: 1.55317475966 , training acc: 0.689285687038 , valid loss: 1.68947911263 , valid acc: 0.589999953906
# epoch: 65 , training loss: 1.55169016974 , training acc: 0.680714275156 , valid loss: 1.7280617555 , valid acc: 0.596666634083
# epoch: 66 , training loss: 1.53982486044 , training acc: 0.677857117993 , valid loss: 1.69142993291 , valid acc: 0.629999975363
# epoch: 67 , training loss: 1.53782448598 , training acc: 0.684285687549 , valid loss: 1.73403048515 , valid acc: 0.589999953906
# epoch: 68 , training loss: 1.4959212201 , training acc: 0.703571417502 , valid loss: 1.58885852496 , valid acc: 0.616666654746
# epoch: 69 , training loss: 1.50776251725 , training acc: 0.679999985865 , valid loss: 1.63167945544 , valid acc: 0.619999965032
# epoch: 70 , training loss: 1.5308516877 , training acc: 0.690714265619 , valid loss: 1.60237888495 , valid acc: 0.63666665554
# epoch: 71 , training loss: 1.48564629044 , training acc: 0.704285698278 , valid loss: 1.63551704089 , valid acc: 0.609999974569
# epoch: 72 , training loss: 1.48956087657 , training acc: 0.675714258637 , valid loss: 1.65376083056 , valid acc: 0.63333328565
# epoch: 73 , training loss: 1.4851189426 , training acc: 0.702857111182 , valid loss: 1.67979939779 , valid acc: 0.599999964237
# epoch: 74 , training loss: 1.49793040752 , training acc: 0.702142821891 , valid loss: 1.620556434 , valid acc: 0.629999975363
# epoch: 75 , training loss: 1.4728159649 , training acc: 0.693571410009 , valid loss: 1.62024346987 , valid acc: 0.65999998649
# epoch: 76 , training loss: 1.46833649703 , training acc: 0.694999975818 , valid loss: 1.58383337657 , valid acc: 0.6199999849
# epoch: 77 , training loss: 1.45401233435 , training acc: 0.692142831428 , valid loss: 1.65721217791 , valid acc: 0.603333334128
# epoch: 78 , training loss: 1.45326934542 , training acc: 0.700714273112 , valid loss: 1.61760934194 , valid acc: 0.596666634083
# epoch: 79 , training loss: 1.48124321869 , training acc: 0.697857124465 , valid loss: 1.5641664664 , valid acc: 0.63666665554
# epoch: 80 , training loss: 1.47056879316 , training acc: 0.711428548609 , valid loss: 1.59091067314 , valid acc: 0.653333306313
# epoch: 81 , training loss: 1.47671364035 , training acc: 0.711428527321 , valid loss: 1.57007050514 , valid acc: 0.616666654746
# epoch: 82 , training loss: 1.42065065248 , training acc: 0.704999983311 , valid loss: 1.57743752003 , valid acc: 0.64999995629
# epoch: 83 , training loss: 1.44290753773 , training acc: 0.699285698789 , valid loss: 1.60118206342 , valid acc: 0.589999973774
# epoch: 84 , training loss: 1.41258685078 , training acc: 0.694999984332 , valid loss: 1.54537423452 , valid acc: 0.643333315849
# epoch: 85 , training loss: 1.43450138399 , training acc: 0.699999979564 , valid loss: 1.54487291972 , valid acc: 0.639999985695
# epoch: 86 , training loss: 1.42014262506 , training acc: 0.704285702535 , valid loss: 1.5800101757 , valid acc: 0.643333295981
# epoch: 87 , training loss: 1.43062921933 , training acc: 0.704999979053 , valid loss: 1.59237619241 , valid acc: 0.636666635672
# epoch: 88 , training loss: 1.39471685886 , training acc: 0.707857119186 , valid loss: 1.60087243716 , valid acc: 0.586666663488
# epoch: 89 , training loss: 1.40423429012 , training acc: 0.701428558145 , valid loss: 1.59767448902 , valid acc: 0.613333304723
# epoch: 90 , training loss: 1.38516966786 , training acc: 0.705714264086 , valid loss: 1.55836888154 , valid acc: 0.646666626136
# epoch: 91 , training loss: 1.39914652279 , training acc: 0.716428548098 , valid loss: 1.54967153072 , valid acc: 0.633333325386
# epoch: 92 , training loss: 1.39589659657 , training acc: 0.712142837899 , valid loss: 1.571773688 , valid acc: 0.583333333333
# epoch: 93 , training loss: 1.40264903648 , training acc: 0.719999973263 , valid loss: 1.58469796181 , valid acc: 0.603333294392
# epoch: 94 , training loss: 1.4181084122 , training acc: 0.714999982289 , valid loss: 1.56455731392 , valid acc: 0.613333324591
# epoch: 95 , training loss: 1.37000205687 , training acc: 0.720714275326 , valid loss: 1.66934967041 , valid acc: 0.589999973774
# epoch: 96 , training loss: 1.37713181121 , training acc: 0.717857118164 , valid loss: 1.60597570737 , valid acc: 0.599999984105
# epoch: 97 , training loss: 1.37664867299 , training acc: 0.720714262554 , valid loss: 1.59848252932 , valid acc: 0.633333305518
# epoch: 97 , pass acc: 0.666666646798 , current acc: 0.676666637262
# epoch: 98 , training loss: 1.36324622801 , training acc: 0.708571412734 , valid loss: 1.49182673295 , valid acc: 0.676666637262
# epoch: 99 , training loss: 1.3457190139 , training acc: 0.70714282138 , valid loss: 1.51932930946 , valid acc: 0.649999996026
# epoch: 100 , training loss: 1.37368002108 , training acc: 0.73785713315 , valid loss: 1.4871806701 , valid acc: 0.656666656335
# epoch: 101 , training loss: 1.35357855047 , training acc: 0.717142833131 , valid loss: 1.57496722539 , valid acc: 0.623333315055
# epoch: 102 , training loss: 1.35357744353 , training acc: 0.729999976499 , valid loss: 1.51697468758 , valid acc: 0.626666625341
# epoch: 103 , training loss: 1.34583824873 , training acc: 0.727857134172 , valid loss: 1.52139739196 , valid acc: 0.633333305518
# epoch: 104 , training loss: 1.34184667042 , training acc: 0.733571410179 , valid loss: 1.54582484563 , valid acc: 0.636666675409
# epoch: 105 , training loss: 1.33686707701 , training acc: 0.740714269025 , valid loss: 1.49950579802 , valid acc: 0.659999966621
# epoch: 106 , training loss: 1.34324226209 , training acc: 0.73714282683 , valid loss: 1.51619939009 , valid acc: 0.639999985695
# epoch: 107 , training loss: 1.32130472149 , training acc: 0.73785711612 , valid loss: 1.52172199885 , valid acc: 0.583333293597
# epoch: 108 , training loss: 1.31134579863 , training acc: 0.718571411712 , valid loss: 1.49491178989 , valid acc: 0.623333334923
# epoch: 109 , training loss: 1.34298992157 , training acc: 0.724285700491 , valid loss: 1.5380572478 , valid acc: 0.603333294392
# epoch: 110 , training loss: 1.32665649482 , training acc: 0.727857129914 , valid loss: 1.52946186066 , valid acc: 0.583333313465
# epoch: 111 , training loss: 1.30186295509 , training acc: 0.728571402175 , valid loss: 1.48160191377 , valid acc: 0.629999975363
# epoch: 112 , training loss: 1.30143133232 , training acc: 0.714285692998 , valid loss: 1.53588569164 , valid acc: 0.593333323797
# epoch: 113 , training loss: 1.28811292989 , training acc: 0.746428557805 , valid loss: 1.51231185595 , valid acc: 0.6199999849
# epoch: 114 , training loss: 1.30981923853 , training acc: 0.733571418694 , valid loss: 1.46953256925 , valid acc: 0.659999966621
# epoch: 115 , training loss: 1.29340715068 , training acc: 0.733571410179 , valid loss: 1.49673851331 , valid acc: 0.606666624546
# epoch: 116 , training loss: 1.30972151245 , training acc: 0.750714272261 , valid loss: 1.49123871326 , valid acc: 0.633333305518
# epoch: 117 , training loss: 1.28814974853 , training acc: 0.727142823594 , valid loss: 1.45696123441 , valid acc: 0.65999998649
# epoch: 118 , training loss: 1.27272208248 , training acc: 0.730714270047 , valid loss: 1.51081140836 , valid acc: 0.599999984105
# epoch: 119 , training loss: 1.25635362523 , training acc: 0.748571408646 , valid loss: 1.43651902676 , valid acc: 0.613333304723
# epoch: 120 , training loss: 1.28713471549 , training acc: 0.737857120378 , valid loss: 1.48364639282 , valid acc: 0.63666665554
# epoch: 121 , training loss: 1.27693932397 , training acc: 0.727857129914 , valid loss: 1.50219277541 , valid acc: 0.60333331426
# epoch: 122 , training loss: 1.26227977446 , training acc: 0.749999987228 , valid loss: 1.40593540668 , valid acc: 0.65999998649
# epoch: 123 , training loss: 1.26611774308 , training acc: 0.740714281797 , valid loss: 1.47461811701 , valid acc: 0.629999975363
# epoch: 124 , training loss: 1.26215264627 , training acc: 0.75571427175 , valid loss: 1.37452479204 , valid acc: 0.666666646798
# epoch: 125 , training loss: 1.25621291569 , training acc: 0.737142835345 , valid loss: 1.40494191647 , valid acc: 0.653333286444
# epoch: 126 , training loss: 1.23340810197 , training acc: 0.735714261021 , valid loss: 1.43108602365 , valid acc: 0.669999976953
# epoch: 127 , training loss: 1.22415469374 , training acc: 0.760714279754 , valid loss: 1.46215625604 , valid acc: 0.616666634878
# epoch: 128 , training loss: 1.23342826537 , training acc: 0.758571407625 , valid loss: 1.45790040493 , valid acc: 0.623333295186
# epoch: 129 , training loss: 1.24410293783 , training acc: 0.739999979734 , valid loss: 1.43600241343 , valid acc: 0.633333305518
# epoch: 130 , training loss: 1.20977280821 , training acc: 0.73142855508 , valid loss: 1.42746881644 , valid acc: 0.616666674614
# epoch: 131 , training loss: 1.2327112811 , training acc: 0.76857141086 , valid loss: 1.38090348244 , valid acc: 0.656666636467
# epoch: 132 , training loss: 1.22347086668 , training acc: 0.749285710709 , valid loss: 1.46551601092 , valid acc: 0.606666624546
# epoch: 133 , training loss: 1.22394770384 , training acc: 0.752857106073 , valid loss: 1.47016521295 , valid acc: 0.613333324591
# epoch: 134 , training loss: 1.21836555856 , training acc: 0.764285687889 , valid loss: 1.41624681155 , valid acc: 0.663333296776
# epoch: 135 , training loss: 1.19205224514 , training acc: 0.764999972922 , valid loss: 1.38379502296 , valid acc: 0.646666665872
# epoch: 136 , training loss: 1.22460598605 , training acc: 0.761428560529 , valid loss: 1.41995473703 , valid acc: 0.629999975363
# epoch: 137 , training loss: 1.18709443297 , training acc: 0.772857112544 , valid loss: 1.46226068338 , valid acc: 0.599999984105
# epoch: 138 , training loss: 1.21393190963 , training acc: 0.773571406092 , valid loss: 1.42557660739 , valid acc: 0.629999975363
# epoch: 139 , training loss: 1.17717289073 , training acc: 0.746428545032 , valid loss: 1.40454332034 , valid acc: 0.623333315055
# epoch: 140 , training loss: 1.20343395642 , training acc: 0.76857141086 , valid loss: 1.4023958842 , valid acc: 0.663333296776
# epoch: 141 , training loss: 1.20590054137 , training acc: 0.754285697426 , valid loss: 1.42034077644 , valid acc: 0.623333315055
# epoch: 142 , training loss: 1.18350236756 , training acc: 0.747142825808 , valid loss: 1.40758391221 , valid acc: 0.626666645209
# epoch: 143 , training loss: 1.18415910006 , training acc: 0.772857116801 , valid loss: 1.39454964797 , valid acc: 0.63666665554
# epoch: 144 , training loss: 1.18912302596 , training acc: 0.753571403878 , valid loss: 1.45778218905 , valid acc: 0.596666653951
# epoch: 144 , pass acc: 0.676666637262 , current acc: 0.689999997616
# epoch: 145 , training loss: 1.17384326458 , training acc: 0.778571405581 , valid loss: 1.34671386083 , valid acc: 0.689999997616
# epoch: 146 , training loss: 1.1698470286 , training acc: 0.767142828022 , valid loss: 1.39599148432 , valid acc: 0.65999998649
# epoch: 147 , training loss: 1.18578773737 , training acc: 0.767857117312 , valid loss: 1.39785218239 , valid acc: 0.633333325386
# epoch: 148 , training loss: 1.18177719627 , training acc: 0.778571401324 , valid loss: 1.3659337759 , valid acc: 0.676666637262
# epoch: 149 , training loss: 1.16937160492 , training acc: 0.775714265449 , valid loss: 1.41892484824 , valid acc: 0.616666634878
# epoch: 150 , training loss: 1.16551194872 , training acc: 0.764285687889 , valid loss: 1.375030001 , valid acc: 0.633333325386
# epoch: 151 , training loss: 1.16090898003 , training acc: 0.793571421078 , valid loss: 1.35064256191 , valid acc: 0.656666636467
# epoch: 152 , training loss: 1.13750687667 , training acc: 0.769999976669 , valid loss: 1.37068859736 , valid acc: 0.626666665077
# epoch: 153 , training loss: 1.16422599554 , training acc: 0.787857119526 , valid loss: 1.39893003305 , valid acc: 0.626666645209
# epoch: 154 , training loss: 1.15289338997 , training acc: 0.787857128041 , valid loss: 1.34386130174 , valid acc: 0.663333316644
# epoch: 155 , training loss: 1.15315054144 , training acc: 0.767142840794 , valid loss: 1.33260822296 , valid acc: 0.643333295981
# epoch: 156 , training loss: 1.14812881606 , training acc: 0.792857119015 , valid loss: 1.37090937297 , valid acc: 0.649999976158
# epoch: 157 , training loss: 1.13604996034 , training acc: 0.769285691636 , valid loss: 1.35248148441 , valid acc: 0.679999967416
# epoch: 158 , training loss: 1.12735996076 , training acc: 0.778571401324 , valid loss: 1.32005266349 , valid acc: 0.679999987284
# epoch: 159 , training loss: 1.12527458157 , training acc: 0.786428540945 , valid loss: 1.35541713238 , valid acc: 0.636666675409
# epoch: 160 , training loss: 1.12418141535 , training acc: 0.770714261702 , valid loss: 1.34729834398 , valid acc: 0.616666654746
# epoch: 161 , training loss: 1.13521180834 , training acc: 0.777142831257 , valid loss: 1.36075774829 , valid acc: 0.639999985695
# epoch: 162 , training loss: 1.13076496976 , training acc: 0.781428549971 , valid loss: 1.36822160085 , valid acc: 0.659999966621
# epoch: 163 , training loss: 1.12135995286 , training acc: 0.78999998314 , valid loss: 1.34326354663 , valid acc: 0.636666635672
# epoch: 164 , training loss: 1.11648625987 , training acc: 0.79214283824 , valid loss: 1.37575984001 , valid acc: 0.63666665554
# epoch: 165 , training loss: 1.10435177599 , training acc: 0.791428561722 , valid loss: 1.31753730774 , valid acc: 0.653333306313
# epoch: 166 , training loss: 1.12198853493 , training acc: 0.791428548949 , valid loss: 1.37804571788 , valid acc: 0.629999975363
# epoch: 167 , training loss: 1.10589746067 , training acc: 0.768571423633 , valid loss: 1.3420617183 , valid acc: 0.613333324591
# epoch: 168 , training loss: 1.10172764744 , training acc: 0.787857115269 , valid loss: 1.34012842178 , valid acc: 0.599999984105
# epoch: 169 , training loss: 1.11449064527 , training acc: 0.800714250122 , valid loss: 1.34421523412 , valid acc: 0.6199999849
# epoch: 170 , training loss: 1.08520769221 , training acc: 0.789999987398 , valid loss: 1.30770222346 , valid acc: 0.683333297571
# epoch: 171 , training loss: 1.07730869736 , training acc: 0.797142837729 , valid loss: 1.31950354576 , valid acc: 0.646666646004
# epoch: 172 , training loss: 1.0922925302 , training acc: 0.786428553717 , valid loss: 1.35133500894 , valid acc: 0.623333315055
# epoch: 173 , training loss: 1.08194272007 , training acc: 0.807142840964 , valid loss: 1.34760057926 , valid acc: 0.653333306313
# epoch: 174 , training loss: 1.08196577004 , training acc: 0.789285706622 , valid loss: 1.3119614919 , valid acc: 0.63666665554
# epoch: 175 , training loss: 1.07246808495 , training acc: 0.809285696064 , valid loss: 1.35987309615 , valid acc: 0.623333334923
# epoch: 176 , training loss: 1.07082882949 , training acc: 0.787857128041 , valid loss: 1.33256510894 , valid acc: 0.633333325386
# epoch: 177 , training loss: 1.07052614433 , training acc: 0.807142849479 , valid loss: 1.34664773941 , valid acc: 0.626666625341
# epoch: 178 , training loss: 1.06831623827 , training acc: 0.802857122251 , valid loss: 1.29873768489 , valid acc: 0.643333315849
# epoch: 179 , training loss: 1.06530691045 , training acc: 0.793571416821 , valid loss: 1.29251503944 , valid acc: 0.673333307107
# epoch: 180 , training loss: 1.05150294304 , training acc: 0.810714274645 , valid loss: 1.27733989557 , valid acc: 0.669999957085
# epoch: 181 , training loss: 1.06027353236 , training acc: 0.80785712174 , valid loss: 1.27019969622 , valid acc: 0.676666637262
# epoch: 182 , training loss: 1.05193944488 , training acc: 0.815714261362 , valid loss: 1.34526809057 , valid acc: 0.626666645209
# epoch: 183 , training loss: 1.05657263313 , training acc: 0.81428569981 , valid loss: 1.32173812389 , valid acc: 0.606666644414
# epoch: 184 , training loss: 1.04026531322 , training acc: 0.805714270898 , valid loss: 1.28210119406 , valid acc: 0.646666646004
# epoch: 185 , training loss: 1.05309736303 , training acc: 0.810714257615 , valid loss: 1.33374166489 , valid acc: 0.63666665554
# epoch: 186 , training loss: 1.03709636416 , training acc: 0.794285672052 , valid loss: 1.26681220531 , valid acc: 0.666666646798
# epoch: 187 , training loss: 1.04006432635 , training acc: 0.814285691295 , valid loss: 1.24353559812 , valid acc: 0.669999976953
# epoch: 188 , training loss: 1.04157087633 , training acc: 0.807142836707 , valid loss: 1.28800308704 , valid acc: 0.633333325386
# epoch: 189 , training loss: 1.03088786772 , training acc: 0.816428546395 , valid loss: 1.31934805711 , valid acc: 0.643333295981
# epoch: 190 , training loss: 1.03363832406 , training acc: 0.816428567682 , valid loss: 1.29850240548 , valid acc: 0.649999976158
# epoch: 191 , training loss: 1.03149575421 , training acc: 0.808571406773 , valid loss: 1.29158624013 , valid acc: 0.626666665077
# epoch: 192 , training loss: 1.02905701739 , training acc: 0.800714271409 , valid loss: 1.29826243718 , valid acc: 0.646666646004
# epoch: 193 , training loss: 1.02497036116 , training acc: 0.813571406262 , valid loss: 1.3480070432 , valid acc: 0.639999985695
# epoch: 194 , training loss: 1.0166658674 , training acc: 0.802857130766 , valid loss: 1.32548379898 , valid acc: 0.609999994437
# epoch: 195 , training loss: 1.02206483058 , training acc: 0.822142839432 , valid loss: 1.29571600755 , valid acc: 0.636666635672
# epoch: 196 , training loss: 0.994606775897 , training acc: 0.817142848458 , valid loss: 1.31538939476 , valid acc: 0.616666634878
# epoch: 197 , training loss: 1.02512193578 , training acc: 0.816428567682 , valid loss: 1.32597275575 , valid acc: 0.626666665077
# epoch: 198 , training loss: 1.01186359354 , training acc: 0.820000001362 , valid loss: 1.32695619265 , valid acc: 0.629999995232
# epoch: 199 , training loss: 1.00883281657 , training acc: 0.832142842667 , valid loss: 1.255600969 , valid acc: 0.663333316644
# epoch: 200 , training loss: 1.00199111445 , training acc: 0.835714263575 , valid loss: 1.23917770386 , valid acc: 0.673333326976
# epoch: 201 , training loss: 0.998870398317 , training acc: 0.840714263065 , valid loss: 1.26539508502 , valid acc: 0.653333306313
# epoch: 202 , training loss: 0.989438968045 , training acc: 0.820714290653 , valid loss: 1.27549688021 , valid acc: 0.656666636467
# epoch: 203 , training loss: 0.993519795792 , training acc: 0.81428569981 , valid loss: 1.23290113608 , valid acc: 0.673333307107
# epoch: 204 , training loss: 0.999338588544 , training acc: 0.827142847436 , valid loss: 1.28511063258 , valid acc: 0.646666626136
# epoch: 205 , training loss: 0.997858362538 , training acc: 0.83214283841 , valid loss: 1.28161780039 , valid acc: 0.669999976953
# epoch: 206 , training loss: 0.996821194887 , training acc: 0.831428570407 , valid loss: 1.28667736053 , valid acc: 0.626666665077
# epoch: 207 , training loss: 0.974852817399 , training acc: 0.834285702024 , valid loss: 1.25746178627 , valid acc: 0.656666676203
# epoch: 208 , training loss: 0.977806555373 , training acc: 0.819285699299 , valid loss: 1.26761066914 , valid acc: 0.649999976158
# epoch: 209 , training loss: 0.971102952957 , training acc: 0.827857136726 , valid loss: 1.28839993477 , valid acc: 0.646666665872
# epoch: 210 , training loss: 0.969330732312 , training acc: 0.832142842667 , valid loss: 1.26249361038 , valid acc: 0.6199999849
# epoch: 211 , training loss: 0.975803596633 , training acc: 0.852857138429 , valid loss: 1.31500442823 , valid acc: 0.636666635672
# epoch: 212 , training loss: 0.979091529335 , training acc: 0.82285713298 , valid loss: 1.27493111293 , valid acc: 0.649999976158
# epoch: 213 , training loss: 0.974821252482 , training acc: 0.84714284965 , valid loss: 1.28421902657 , valid acc: 0.639999985695
# epoch: 214 , training loss: 0.965959076371 , training acc: 0.843571415969 , valid loss: 1.30747699738 , valid acc: 0.63666665554
# epoch: 215 , training loss: 0.964736972536 , training acc: 0.833571412734 , valid loss: 1.22130767504 , valid acc: 0.65999998649
# epoch: 216 , training loss: 0.961842183556 , training acc: 0.828571396215 , valid loss: 1.27447358767 , valid acc: 0.623333295186
# epoch: 217 , training loss: 0.950807226556 , training acc: 0.84785712191 , valid loss: 1.22435462475 , valid acc: 0.679999967416
# epoch: 218 , training loss: 0.95144503883 , training acc: 0.84499999455 , valid loss: 1.24986712138 , valid acc: 0.6199999849
# epoch: 219 , training loss: 0.936530632632 , training acc: 0.841428582157 , valid loss: 1.22306720416 , valid acc: 0.63666665554
# epoch: 220 , training loss: 0.941373667547 , training acc: 0.849999985525 , valid loss: 1.30784229438 , valid acc: 0.606666664282
# epoch: 221 , training loss: 0.940703004599 , training acc: 0.835714263575 , valid loss: 1.2362267971 , valid acc: 0.64999995629
# epoch: 222 , training loss: 0.951310800655 , training acc: 0.867142847606 , valid loss: 1.2557258606 , valid acc: 0.659999966621
# epoch: 223 , training loss: 0.930268641029 , training acc: 0.848571428231 , valid loss: 1.25416517258 , valid acc: 0.646666646004
# epoch: 224 , training loss: 0.93732343827 , training acc: 0.845714258296 , valid loss: 1.25520471732 , valid acc: 0.646666626136
# epoch: 225 , training loss: 0.919138878584 , training acc: 0.852857142687 , valid loss: 1.26480360826 , valid acc: 0.626666645209
# epoch: 226 , training loss: 0.918383219412 , training acc: 0.854285712753 , valid loss: 1.26255897681 , valid acc: 0.636666635672
# epoch: 227 , training loss: 0.905963620969 , training acc: 0.860714273793 , valid loss: 1.23239660263 , valid acc: 0.653333306313
# epoch: 228 , training loss: 0.913285723754 , training acc: 0.854285738298 , valid loss: 1.23733854294 , valid acc: 0.613333304723
# epoch: 229 , training loss: 0.913102247885 , training acc: 0.857857125146 , valid loss: 1.22772979736 , valid acc: 0.646666646004
# epoch: 230 , training loss: 0.90921499048 , training acc: 0.850000015327 , valid loss: 1.21686037381 , valid acc: 0.643333315849
# epoch: 231 , training loss: 0.914457759687 , training acc: 0.847857147455 , valid loss: 1.18883494536 , valid acc: 0.666666646798
# epoch: 232 , training loss: 0.922236395734 , training acc: 0.854285691466 , valid loss: 1.2666525046 , valid acc: 0.609999974569
# epoch: 233 , training loss: 0.908456981182 , training acc: 0.862857141665 , valid loss: 1.22833788395 , valid acc: 0.663333316644
# epoch: 234 , training loss: 0.898704094546 , training acc: 0.852142849139 , valid loss: 1.23627702395 , valid acc: 0.663333316644
# epoch: 235 , training loss: 0.911412132638 , training acc: 0.867857153927 , valid loss: 1.18349794547 , valid acc: 0.669999976953
# epoch: 236 , training loss: 0.900279266494 , training acc: 0.861428567341 , valid loss: 1.27282269796 , valid acc: 0.639999985695
# epoch: 237 , training loss: 0.903792449406 , training acc: 0.863571435213 , valid loss: 1.23995661736 , valid acc: 0.6199999849
# epoch: 238 , training loss: 0.901114970446 , training acc: 0.852142853396 , valid loss: 1.18029554685 , valid acc: 0.683333277702
# epoch: 239 , training loss: 0.88391820022 , training acc: 0.85428571701 , valid loss: 1.1967990001 , valid acc: 0.640000005563
# epoch: 240 , training loss: 0.887766752924 , training acc: 0.87571430632 , valid loss: 1.21572538217 , valid acc: 0.623333295186
# epoch: 241 , training loss: 0.888278275728 , training acc: 0.857142865658 , valid loss: 1.148792545 , valid acc: 0.66666662693
# epoch: 242 , training loss: 0.874729407685 , training acc: 0.86571429457 , valid loss: 1.27174639702 , valid acc: 0.629999975363
# epoch: 243 , training loss: 0.883056014776 , training acc: 0.8592857165 , valid loss: 1.19108728568 , valid acc: 0.653333306313
# epoch: 244 , training loss: 0.876344463655 , training acc: 0.883571424655 , valid loss: 1.22322555383 , valid acc: 0.616666615009
# epoch: 245 , training loss: 0.885281664985 , training acc: 0.874285719224 , valid loss: 1.25567277273 , valid acc: 0.603333294392
# break epoch: 245
